# %%
# This is a code cell, and this line is a comment, which is ignored by Python
5+15/3
# Out:
# 10.0

# %% [markdown]
# This is a markdown cell in which you can write text. Markdown cells use Markdown formatting.

# %% [markdown]
# ## About markdown cells
# Markdown cells use markdown formatting for formatting the text. This makes text more readable and visually structured without relying on complex formatting menus or software. Some common  Markdown formatting examples are:
#
# # Heading 1
# ## Heading 2
# ### Heading 3 etc.
# **Bold text**
#
# *Italic text*
#
# ***Bold italic text***
#
# > Item in an enumeration
#
# When you are done editing, click on the checkmark at the top right of the cell. The text will now appear with Markdown formatting in your notebook.

# %%
3*4+4
# Out:
# 16

# %% [markdown]
# # **How interesting is the following text**
#
# ## This text isn't interesting
#
# #### *Hala Madrid y nada mas*

# %%
81/9
# Out:
# 9.0

# %% [markdown]
# ###### *Waterstof inhoud 3 4 yx*

# %%
print(8*8)
print(32/4)
print(15+31+2)
# Out:
# 64
# 8.0
# 48

# %%
print(3*(6/2))
# Out:
# 9.0

# %%
# Looking at braskets
print(6*5-2*10/4)
print((6*5-2*10)/4)
print((6 * 5 - 2 * 10 ) / 4 )
print( ( (6 * 5) - (2 * 10) ) / 4 )
# Out:
# 25.0
# 2.5
# 2.5
# 2.5

# %%
print("Hello World")
print('The lesson ends at 4:15pm')
# Out:
# Hello World
# The lesson ends at 4:15pm

# %% [markdown]
# # Exercise 1

# %%
print("Ivan van Vreeswijk")
print(21/2)
# Out:
# Ivan van Vreeswijk
# 10.5

# %%
print( “hi everyone! ” )
print(‘hi evryone!”)
print(‘hi everyone!’).
# Out:
#   Cell In[35], line 1
#     print( “hi everyone! ” )
#            ^
# SyntaxError: invalid character '“' (U+201C)

# %%
type(5)
# Out:
# int

# %%
type("John")
# Out:
# str

# %%
type(.4e7)
# Out:
# float

# %%
print(type("Ivan"))
print(type(.4e7))
print(type(15))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %%
x = 3
print(x**6)
# Out:
# 729

# %%
name = "Ivan"
print(name)
# Out:
# Ivan

# %%
name = "Jenny"
age = 15.364+1.273

print(f'Hi, my name is {name} and I am {age:.2f} years old.')
# Out:
# Hi, my name is Jenny and I am 16.64 years old.

# %%
name = "Ivan"
age = 6+15

print(f'Hi, my name is {name} and I am {age} years old.')
# Out:
# Hi, my name is Ivan and I am 21 years old.

# %%
int(1.56)
# this is the same
x = 1.56
int(x)

# another option
print(int(1.56))
# Out:
# 1

# %%
print(float(1.78))
# Out:
# 1.78

# %%
max(7, 2, 21, 10, 5)
# Out:
# 21

# %%
min(7, 2, 21, 10, 5)
# Out:
# 2

# %%
import numpy

# Ignore this sentence

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 18, 12] 

plt.plot(x, y) 
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title('Simple graph') 

plt.show()

# %%
score = 34

if score >= 90:
    print("Grade: A.")
elif score >= 60:
    print("Grade: B.")
else:
    print("Grade: C")
# Out:
# Grade: C

# %%
# Ask the user to enter their age
age = int(input("Enter your age: "))

# Determine the ticket price
if age < 12:
    price = 8
elif age < 65:
    price = 10
else: price = 9

# Print the result
print(f"Your ticket price is ${price}.")
# Out:
# Your ticket price is $8.

# %%
for water in "yes":
    print(water)
print("Done!")
# Out:
# y
# e
# s
# Done!

# %%
#   number = 1
#   while number <= 5:
#   print(f"This is number {number}")
#   number += 1 # Increase number by 1 each time

friends = ["Floyd", "Baran", "Aaron"]
    print(f"Hello {friends}")

    for word in friends:
        print(word):
# Out:
#   Cell In[92], line 7
#     print(f"Hello {friends}")
#     ^
# IndentationError: unexpected indent
